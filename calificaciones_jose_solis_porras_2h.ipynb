# %% [markdown]
# <a href="https://colab.research.google.com/github/josesolisporras2h/calificaciones-2-act-jose-solis/blob/main/calificaciones_jose_solis_porras_2h.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# programa de promedios

calificacion=float(input("ingresa tu calificacion: "))

if calificacion >= 9 and calificacion < 10:
  print("exentado")
elif calificacion >= 7:
  print("aprobado")
elif calificacion < 7:
  print("reprobado")
# Out:
# ingresa tu calificacion: 9
# exentado

# %%
# programa de promedios

calificacion=float(input("ingresa tu calificacion: "))

if calificacion >= 9 and calificacion < 10:
  print("exentado")
elif calificacion >= 7:
  print("aprobado")
elif calificacion < 7:
  print("reprobado")
# Out:
# ingresa tu calificacion: 8
# aprobado

# %%
# programa de promedios

calificacion=float(input("ingresa tu calificacion: "))

if calificacion >= 9 and calificacion < 10:
  print("exentado")
elif calificacion >= 7:
  print("aprobado")
elif calificacion < 7:
  print("reprobado")
# Out:
# ingresa tu calificacion: 6
# reprobado
